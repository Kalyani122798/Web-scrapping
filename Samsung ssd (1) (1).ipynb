# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
URL="https://www.flipkart.com/samsung-870-evo-500-gb-laptop-desktop-internal-solid-state-drive-ssd-mz-77e500bw/p/itme29010ec39f84?pid=IHDGY4JHGMKR4DHW&lid=LSTIHDGY4JHGMKR4DHWSWWFIR&marketplace=FLIPKART&store=6bo%2Fjdy%2Fdus&srno=b_1_1&otracker=browse&fm=organic&iid=en_GrfQbos7AGKtXIgZ0ZBmFgiAqd41WyZx2XQWLzE9uj38lSOqoqolfAFRMP5IJ3eY6wTQ790kPz78QXUuIge0Nw%3D%3D&ppt=hp&ppn=homepage&ssid=hp3id1c5tc0000001701336318578"

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
r=requests.get(URL)
data=r.content
print(data)
# Out:
# b'<!doctype html><html lang="en"><head><link href="https://rukminim2.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.905c37.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.615ed9.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><meta name="robots" content="noodp"/><link rel="shortcut icon" href="https:///www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/apple-touch-icon-57x5
# ...

# %%
#prettify the codes of HTML page
soup=BeautifulSoup(data,'html.parser')
soup.prettify
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
# ...

# %%
title=soup.title
print(type(soup))          # beautifulsoup
print(type(title))         # tag
print(type(title.string))  # navigablestring
# Out:
# <class 'bs4.BeautifulSoup'>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.NavigableString'>

# %%
title=soup.title
title
# Out:
# <title>SAMSUNG 870 Evo 500 GB Laptop, Desktop Internal Solid State Drive (SSD) (MZ-77E500BW) - SAMSUNG : Flipkart.com</title>

# %%
price=soup.find_all(class_="_30jeq3 _16Jk6d")
price
# Out:
# [<div class="_30jeq3 _16Jk6d">₹3,649</div>]

# %%
price[0].get_text()
# Out:
# '₹3,649'

# %%
names=soup.find_all(class_="_2sc7ZR _2V5EHH")
names=list(names)
print(type(names))
print(names)
len(names)
# Out:
# <class 'list'>
# [<p class="_2sc7ZR _2V5EHH">Sourabh Kumar</p>, <p class="_2sc7ZR _2V5EHH">Kunal</p>, <p class="_2sc7ZR _2V5EHH">Satadru Roy</p>, <p class="_2sc7ZR _2V5EHH">Lokesh Hi</p>, <p class="_2sc7ZR _2V5EHH">V Ravichandran Menon</p>, <p class="_2sc7ZR _2V5EHH">Sangramsingh Patil</p>, <p class="_2sc7ZR _2V5EHH">Ashvjit  Satpute </p>, <p class="_2sc7ZR _2V5EHH">Flipkart Customer</p>, <p class="_2sc7ZR _2V5EHH">Amit Kumar</p>, <p class="_2sc7ZR _2V5EHH">Subhajit  De </p>]
# 10

# %%
names[0].get_text()
# Out:
# 'Sourabh Kumar'

# %%
# list of customer names
c_names=[]
for i in names:
    c_names.append(i.get_text())
c_names
# Out:
# ['Sourabh Kumar',
#  'Kunal',
#  'Satadru Roy',
#  'Lokesh Hi',
#  'V Ravichandran Menon',
#  'Sangramsingh Patil',
#  'Ashvjit  Satpute ',
#  'Flipkart Customer',
#  'Amit Kumar',
#  'Subhajit  De ']

# %%
comment = soup.find_all(class_="_2-N8zT")
comment
# Out:
# [<p class="_2-N8zT">Classy product</p>,
#  <p class="_2-N8zT">Classy product</p>,
#  <p class="_2-N8zT">Mind-blowing purchase</p>,
#  <p class="_2-N8zT">Simply awesome</p>,
#  <p class="_2-N8zT">Wonderful</p>,
#  <p class="_2-N8zT">Brilliant</p>,
#  <p class="_2-N8zT">Just wow!</p>,
#  <p class="_2-N8zT">Brilliant</p>,
#  <p class="_2-N8zT">Super!</p>,
#  <p class="_2-N8zT">Pretty good</p>]

# %%
review_comment = []
for i in comment:
    review_comment.append(i.get_text())
review_comment
# Out:
# ['Classy product',
#  'Classy product',
#  'Mind-blowing purchase',
#  'Simply awesome',
#  'Wonderful',
#  'Brilliant',
#  'Just wow!',
#  'Brilliant',
#  'Super!',
#  'Pretty good']

# %%
stars=soup.find_all('div',class_="_3LWZlK _1BLPMq")
stars
# Out:
# [<div class="_3LWZlK _1BLPMq">5<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK _1BLPMq">5<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK _1BLPMq">5<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK _1BLPMq">5<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK _1BLPMq">5<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK _1BLPMq">5<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK _1BLPMq">5<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK _1BLPMq">5<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK _1BLPMq">5<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK _1BLPMq">4<img class="_1wB99o" src="..."/></div>]

# %%
s_stars=[]
for i in stars:
    s_stars.append(i.get_text())
s_stars
# Out:
# ['5', '5', '5', '5', '5', '5', '5', '5', '5', '4']

# %%
review = soup.find_all("div",class_="t-ZTKy")
review
# Out:
# [<div class="t-ZTKy"><div><div class="">The SSD is awesome for the price of ~5000 Ruppes. If you are getting it for more, then please buy it from somewhere else because it is the maximum price it is sold, and at many places you can get even less than 5000. The speed is as expected, pretty good. <br/>       For those of you thinking about whether it will work in you laptop or not, so I would say go to the crucial website and search for you laptop compatible SSD. If that shows SSD with similar configuration as this one, then definitely y...</div><span class="_1BWGvX"><span>READ MORE</span></span></div></div>,
# ...

# %%
cust_review=[]
for i in review:
    cust_review.append(i.get_text())
cust_review
# Out:
# ['The SSD is awesome for the price of ~5000 Ruppes. If you are getting it for more, then please buy it from somewhere else because it is the maximum price it is sold, and at many places you can get even less than 5000. The speed is as expected, pretty good.        For those of you thinking about whether it will work in you laptop or not, so I would say go to the crucial website and search for you laptop compatible SSD. If that shows SSD with similar configuration as this one, then definitely y...READ MORE',
# ...

# %%
anchor=soup.find_all("a")
anchor
# Out:
# [<a href="/"><img alt="Flipkart" class="_2xm1JU" src="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/img/flipkart-plus_8d85f4.png" title="Flipkart" width="75"/></a>,
#  <a class="_21ljIi" href="/plus">Explore<!-- --> <span class="_2FVHGh">Plus</span><img src="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/img/plus_aef861.png" width="10"/></a>,
#  <a class="_1_3w1N" href="/account/login?ret=/samsung-870-evo-500-gb-laptop-desktop-internal-solid-state-drive-ssd-mz-77e500bw/p/itme29010ec39f84%3Fpid%3DIHDGY4JHGMKR4DHW%26lid%3DLSTIHDGY4JHGMKR4DHWSWWFIR%26marketplace%3DFLIPKART%26store%3D6bo%252Fjdy%252Fdus%26srno%3Db_1_1%26otracker%3Dbrowse%26fm%3Dorganic%26iid%3Den_GrfQbos7AGKtXIgZ0ZBmFgiAqd41WyZx2XQWLzE9uj38lSOqoqolfAFRMP5IJ3eY6wTQ790kPz78QXUuIge0Nw%253D%253D%26ppt%3Dhp%26ppn%3Dhomepage%26ssid%3Dhp3id1c5tc0000001701336318578">Login</a>,
# ...

# %%
all_links=set()
for link in anchor:
    if(link != "#"):
        link = 'https://www.flipkart.com/boat-airdopes-131-upto-60-hours-asap-charge-bluetooth-headset/p/itm69c331598bc46?pid=ACCGDDVW85MHXTET&lid=LSTACCGDDVW85MHXTETHE1TDH&marketplace=FLIPKART&q=boat+ear+cyan+color&store=0pm%2Ffcn%2F821&srno=s_1_4&otracker=search&otracker1=search&fm=Search&iid=be2f15aa-aa37-46df-8271-27175238c652.ACCGDDVW85MHXTET.SEARCH&ppt=sp&ppn=sp&ssid=ymmmed4uzk0000001701164990738&qH=57504e8cb220e263'
        all_links.add(link)
        print(link)
# Out:
# https://www.flipkart.com/boat-airdopes-131-upto-60-hours-asap-charge-bluetooth-headset/p/itm69c331598bc46?pid=ACCGDDVW85MHXTET&lid=LSTACCGDDVW85MHXTETHE1TDH&marketplace=FLIPKART&q=boat+ear+cyan+color&store=0pm%2Ffcn%2F821&srno=s_1_4&otracker=search&otracker1=search&fm=Search&iid=be2f15aa-aa37-46df-8271-27175238c652.ACCGDDVW85MHXTET.SEARCH&ppt=sp&ppn=sp&ssid=ymmmed4uzk0000001701164990738&qH=57504e8cb220e263
# https://www.flipkart.com/boat-airdopes-131-upto-60-hours-asap-charge-bluetooth-headset/p/itm69c331598bc46?pid=ACCGDDVW85MHXTET&lid=LSTACCGDDVW85MHXTETHE1TDH&marketplace=FLIPKART&q=boat+ear+cyan+color&store=0pm%2Ffcn%2F821&srno=s_1_4&otracker=search&otracker1=search&fm=Search&iid=be2f15aa-aa37-46df-8271-27175238c652.ACCGDDVW85MHXTET.SEARCH&ppt=sp&ppn=sp&ssid=ymmmed4uzk0000001701164990738&qH=57504e8cb220e263
# ...

# %%
import pandas as pd

# %%
consolidated_data = pd.DataFrame({"customers_Name":c_names,'Review_stars':s_stars,"Review_Comment":review_comment,"review":cust_review},index=range(1,11))
print(consolidated_data)
# Out:
#           customers_Name Review_stars         Review_Comment  \
# 1          Sourabh Kumar            5         Classy product
# 2                  Kunal            5         Classy product
# 3            Satadru Roy            5  Mind-blowing purchase
# 4              Lokesh Hi            5         Simply awesome
# 5   V Ravichandran Menon            5              Wonderful
# 6     Sangramsingh Patil            5              Brilliant
# 7      Ashvjit  Satpute             5              Just wow!
# 8      Flipkart Customer            5              Brilliant
# 9             Amit Kumar            5                 Super!
# 10         Subhajit  De             4            Pretty good
#
#                                                review
# 1   The SSD is awesome for the price of ~5000 Rupp...
# 2   Fastest sata ssdSeal and ssd package was brand...
# 3   Loved it. Changed the experience of using PCRE...
# 4      The product is awesome and very lightREAD MORE
# ...

# %% [markdown]
# # Exporting the Dataset into CSV file

# %%
consolidated_data.to_csv("Flipcart_SSD_Review.csv")

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\arpit\\Music'

# %%
df1 = pd.read_csv("Flipcart_SSD_Review.csv")
df1.head()
# Out:
#    Unnamed: 0        customers_Name  Review_stars         Review_Comment  \
# 0           1         Sourabh Kumar             5         Classy product
# 1           2                 Kunal             5         Classy product
# 2           3           Satadru Roy             5  Mind-blowing purchase
# 3           4             Lokesh Hi             5         Simply awesome
# 4           5  V Ravichandran Menon             5              Wonderful
#
#                                               review
# 0  The SSD is awesome for the price of ~5000 Rupp...
# 1  Fastest sata ssdSeal and ssd package was brand...
# 2  Loved it. Changed the experience of using PCRE...
# 3     The product is awesome and very lightREAD MORE
# 4  Excellent product. The Samsung application hel...

# %%
df1 = pd.read_csv("Flipcart_SSD_Review.csv")
df1.tail()
# Out:
#    Unnamed: 0      customers_Name  Review_stars Review_Comment  \
# 5           6  Sangramsingh Patil             5      Brilliant
# 6           7   Ashvjit  Satpute              5      Just wow!
# 7           8   Flipkart Customer             5      Brilliant
# 8           9          Amit Kumar             5         Super!
# 9          10       Subhajit  De              4    Pretty good
#
#                                               review
# 5  Excellent purchase.  My Dell inspiron15 5559 g...
# 6                                      NiceREAD MORE
# 7  Great, now everything is fast, best money i ev...
# 8  Boot time reduces significantly, before it tak...
# 9              Awesome jst as said in specsREAD MORE

# %%
df1.describe()
# Out:
#        Unnamed: 0  Review_stars
# count    10.00000     10.000000
# mean      5.50000      4.900000
# std       3.02765      0.316228
# min       1.00000      4.000000
# 25%       3.25000      5.000000
# 50%       5.50000      5.000000
# 75%       7.75000      5.000000
# max      10.00000      5.000000

# %% [markdown]
# # SORTING THE DATASET FILE

# %%
df1.customers_Name.sort_values()
# Out:
# 8              Amit Kumar
# 6       Ashvjit  Satpute
# 7       Flipkart Customer
# 1                   Kunal
# 3               Lokesh Hi
# 5      Sangramsingh Patil
# 2             Satadru Roy
# 0           Sourabh Kumar
# 9           Subhajit  De
# 4    V Ravichandran Menon
# Name: customers_Name, dtype: object

# %%
df1.customers_Name.sort_values(ascending=False)
# Out:
# 4    V Ravichandran Menon
# 9           Subhajit  De
# 0           Sourabh Kumar
# 2             Satadru Roy
# 5      Sangramsingh Patil
# 3               Lokesh Hi
# 1                   Kunal
# 7       Flipkart Customer
# 6       Ashvjit  Satpute
# 8              Amit Kumar
# Name: customers_Name, dtype: object

# %% [markdown]
# ![image.png](attachment:image.png)
